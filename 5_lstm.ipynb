# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/genAI' # Please adjust the path accordingly
    os.chdir(path_to_file)
    # !pwd
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/genAI

# %% [markdown]
# # 🥙 LSTM on Recipe Data

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own LSTM on the recipes dataset

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
VOCAB_SIZE = 10000
MAX_LEN = 200
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %% [markdown]
# ## 1. Load the data <a name="load"></a>

# %%
# Load the full dataset
with open("full_format_recipes.json") as json_data:
    recipe_data = json.load(json_data)

# %%
recipe_data[0]
# Out:
# {'directions': ['1. Place the stock, lentils, celery, carrot, thyme, and salt in a medium saucepan and bring to a boil. Reduce heat to low and simmer until the lentils are tender, about 30 minutes, depending on the lentils. (If they begin to dry out, add water as needed.) Remove and discard the thyme. Drain and transfer the mixture to a bowl; let cool.',
#   '2. Fold in the tomato, apple, lemon juice, and olive oil. Season with the pepper.',
#   '3. To assemble a wrap, place 1 lavash sheet on a clean work surface. Spread some of the lentil mixture on the end nearest you, leaving a 1-inch border. Top with several slices of turkey, then some of the lettuce. Roll up the lavash, slice crosswise, and serve. If using tortillas, spread the lentils in the center, top with the turkey and lettuce, and fold up the bottom, left side, and right side before rolling away from you.'],
#  'fat': 7.0,
#  'date': '2006-09-01T04:00:00.000Z',
#  'categories': ['Sandwich',
#   'Bean',
#   'Fruit',
#   'Tomato',
#   'turkey',
#   'Vegetable',
#   'Kid-Friendly',
#   'Apple',
#   'Lentil',
#   'Lettuce',
#   'Cookie'],
#  'calories': 426.0,
#  'desc': None,
#  'protein': 30.0,
#  'rating': 2.5,
#  'title': 'Lentil, Apple, and Turkey Wrap ',
#  'ingredients': ['4 cups low-sodium vegetable or chicken stock',
#   '1 cup dried brown lentils',
#   '1/2 cup dried French green lentils',
#   '2 stalks celery, chopped',
#   '1 large carrot, peeled and chopped',
#   '1 sprig fresh thyme',
#   '1 teaspoon kosher salt',
#   '1 medium tomato, cored, seeded, and diced',
#   '1 small Fuji apple, cored and diced',
#   '1 tablespoon freshly squeezed lemon juice',
#   '2 teaspoons extra-virgin olive oil',
#   'Freshly ground black pepper to taste',
#   '3 sheets whole-wheat lavash, cut in half crosswise, or 6 (12-inch) flour tortillas',
#   '3/4 pound turkey breast, thinly sliced',
#   '1/2 head Bibb lettuce'],
#  'sodium': 559.0}

# %%
# Filter the dataset
filtered_data = [
    "Recipe for " + x["title"] + " | " + " ".join(x["directions"])
    for x in recipe_data
    if "title" in x
    and x["title"] is not None
    and "directions" in x
    and x["directions"] is not None
]

# %%
# Count the recipes
n_recipes = len(filtered_data)
print(f"{n_recipes} recipes loaded")
# Out:
# 20111 recipes loaded

# %%
example = filtered_data[9]
print(example)
# Out:
# Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas  | Chop enough parsley leaves to measure 1 tablespoon; reserve. Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan, covered, 5 minutes. Meanwhile, sprinkle gelatin over water in a medium bowl and let soften 1 minute. Strain broth through a fine-mesh sieve into bowl with gelatin and stir to dissolve. Season with salt and pepper. Set bowl in an ice bath and cool to room temperature, stirring. Toss ham with reserved parsley and divide among jars. Pour gelatin on top and chill until set, at least 1 hour. Whisk together mayonnaise, mustard, vinegar, 1/4 teaspoon salt, and 1/4 teaspoon pepper in a large bowl. Stir in celery, cornichons, and potatoes. Pulse peas with marjoram, oil, 1/2 teaspoon pepper, and 1/4 teaspoon salt in a food processor to a coarse mash. Layer peas, then potato salad, over ham.

# %% [markdown]
# ## 2. Tokenise the data

# %%
# Pad the punctuation, to treat them as separate 'words'
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s


text_data = [pad_punctuation(x) for x in filtered_data]

# %%
# Display an example of a recipe
example_data = text_data[9]
example_data
# Out:
# 'Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas | Chop enough parsley leaves to measure 1 tablespoon ; reserve . Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan , covered , 5 minutes . Meanwhile , sprinkle gelatin over water in a medium bowl and let soften 1 minute . Strain broth through a fine - mesh sieve into bowl with gelatin and stir to dissolve . Season with salt and pepper . Set bowl in an ice bath and cool to room temperature , stirring . Toss ham with reserved parsley and divide among jars . Pour gelatin on top and chill until set , at least 1 hour . Whisk together mayonnaise , mustard , vinegar , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a large bowl . Stir in celery , cornichons , and potatoes . Pulse peas with marjoram , oil , 1 / 2 teaspoon pepper , and 1 / 4 teaspoon salt in a food processor to a coarse mash . Layer peas , then potato salad , over ham . '

# %%
# Convert to a Tensorflow Dataset
text_ds = (
    tf.data.Dataset.from_tensor_slices(text_data)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)

# %%
for batch in text_ds:
  print(batch)
  break
# Out:
# tf.Tensor(
# [b'Recipe for Grilled Boneless Salmon Steaks with Horseradish Dill Butter | Stir together butter , horseradish , dill , shallot , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a bowl with a rubber spatula until combined well . Transfer butter to a sheet of parchment or wax paper and roll into a 1 - inch - thick cylinder . Twist ends of parchment to close , then chill until firm , about 20 minutes . Prepare grill for direct - heat cooking over medium - hot charcoal . Put salmon steaks on a cutting board with tail - like flaps nearest you . Halve 1 steak lengthwise by cutting along each side of large center bone . Remove and discard bones ( you will end up with 2 thin pieces of fillet ) . Flip 1 piece over , turning it so rounded thicker portion is nearest you . Push halves together to create a yin - yang presentation , wrapping tail - like flaps around outside of steak . Wrap a piece of kitchen string around outside of steak , going around once or twice , and tie ends . Brush salmon on both sides with oil , then sprinkle with remaining 3 / 4 teaspoon salt and 1 / 2 teaspoon pepper . Oil grill rack , then grill salmon , covered only if using a gas grill , turning over once and if necessary moving to area with no coals underneath to avoid flare - ups , until just cooked through , 6 to 8 minutes total . Serve each fish steak topped with a slice of horseradish butter . '
#  b'Recipe for Creole Seasoning | In a medium bowl combine paprika , dried oregano , ground black pepper , dried basil , kosher salt , cayenne pepper , granulated onion , dried thyme , and granulated garlic . Stir to combine . Store in an airtight container for up to three months . '
#  b'Recipe for Honeydew and Cantaloupe with Cinnamon - Clove Syrup | Bring first 6 ingredients to boil in small saucepan over medium heat . Reduce heat to low and simmer until mixture is reduced to 3 / 4 cup , about 25 minutes . Cool . Strain mixture . Add rum and stir to combine . Refrigerate until cold , at least 1 hour . ( Cinnamon - clove syrup can be prepared 2 days ahead . Keep refrigerated . ) Scoop out enough melon balls from honeydew and cantaloupe to measure 4 cups total . Divide melon balls among 6 bowls . Top with syrup and serve . '
#  b'Recipe for Roast Prime Ribs of Beef with Cracked Pepper Crust | Let the meat stand at room temperature for 1 hour . In a small bowl combine the black pepper , the green pepper , the white pepper , the allspice , the thyme , and the salt and rub the meat with the mixture . Roast the meat rib side down in a roasting pan in a preheated 500\xc2\xb0F . oven for 30 minutes , reduce the heat to 350\xc2\xb0F . , and roast the meat for 1 hour and 45 minutes to 2 hours more , or until a meat thermometer inserted in the fleshy part of the meat registers 130\xc2\xb0F . for medium - rare . Twenty minutes before the roast is done add to the pan the carrots , the garlic , and the shallots , all patted dry . ( Remove the vegetables with a slotted spoon if they brown too quickly . ) Transfer the roast to a heated platter , drain the vegetables on paper towels , and keep them warm , covered loosely . Let the roast rest for at least 20 minutes and up to 30 minutes before carving it . Skim the fat from the pan juices , add the red wine , and deglaze the pan over moderately high heat , scraping up the brown bits . Boil the liquid until it is reduced by half and transfer it to a saucepan . Add the broth and 1 / 4 cup of the Madeira and boil the mixture for 5 minutes . In a small bowl stir together the remaining 2 tablespoons Madeira , the arrowroot , and the mustard and add the mixture to the pan in a stream , whisking . Bring the sauce to a boil , whisking , and boil it for 1 minute . Season the sauce with salt and pepper and transfer it to a heated sauceboat . Arrange the roasted vegetables around the roast with the fresh thyme and serve the roast with sauce . '], shape=(32,), dtype=string)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# %%
# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# %%
# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: .
# 3: ,
# 4: and
# 5: to
# 6: in
# 7: the
# 8: with
# 9: a

# %%
# Display the same example converted to ints
example_tokenised = vectorize_layer(example_data)
print(example_tokenised.numpy())
# Out:
# [  26   16  557    1    8  298  335  189    4 1054  494   27  332  228
#   235  262    5  594   11  133   22  311    2  332   45  262    4  671
#     4   70    8  171    4   81    6    9   65   80    3  121    3   59
#    12    2  299    3   88  650   20   39    6    9   29   21    4   67
#   529   11  164    2  320  171  102    9  374   13  643  306   25   21
#     8  650    4   42    5  931    2   63    8   24    4   33    2  114
#    21    6  178  181 1245    4   60    5  140  112    3   48    2  117
#   557    8  285  235    4  200  292  980    2  107  650   28   72    4
#   108   10  114    3   57  204   11  172    2   73  110  482    3  298
#     3  190    3   11   23   32  142   24    3    4   11   23   32  142
#    33    6    9   30   21    2   42    6  353    3 3224    3    4  150
#     2  437  494    8 1281    3   37    3   11   23   15  142   33    3
#     4   11   23   32  142   24    6    9  291  188    5    9  412  572
#     2  230  494    3   46  335  189    3   20  557    2    0    0    0
#     0    0    0    0    0]

# %%
len(example_tokenised)
# Out:
# 201

# %% [markdown]
# ## 3. Create the Training Set

# %%
# Create the training set of recipes and the same text shifted by one word
def prepare_inputs(text):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


train_ds = text_ds.map(prepare_inputs)

# %%
for sample in train_ds:
  print(sample)
  break
# Out:
# (<tf.Tensor: shape=(32, 200), dtype=int64, numpy=
# array([[  26,   16, 1473, ...,    0,    0,    0],
#        [  26,   16,  479, ...,    2,  710, 1263],
#        [  26,   16, 1340, ...,    5, 1119,    7],
#        ...,
#        [  26,   16,  525, ...,   28,  167,   13],
#        [  26,   16,  272, ...,    0,    0,    0],
#        [  26,   16,  479, ...,    0,    0,    0]])>, <tf.Tensor: shape=(32, 200), dtype=int64, numpy=
# array([[  16, 1473,  472, ...,    0,    0,    0],
#        [  16,  479,  325, ...,  710, 1263,   38],
#        [  16, 1340,  397, ..., 1119,    7,  290],
#        ...,
#        [  16,  525,  335, ...,  167,   13,  541],
#        [  16,  272,   13, ...,    0,    0,    0],
#        [  16,  479,   91, ...,    0,    0,    0]])>)

# %% [markdown]
# ## 4. Build the LSTM <a name="build"></a>

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(N_UNITS, return_sequences=True)(x)
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 100)         1000000
#
#  lstm (LSTM)                 (None, None, 128)         117248
#
#  dense (Dense)               (None, None, 10000)       1290000
#
# =================================================================
# Total params: 2407248 (9.18 MB)
# Trainable params: 2407248 (9.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 5. Train the LSTM <a name="train"></a>

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint_lstm/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

# Tokenize starting prompt
text_generator = TextGenerator(vocab)

# %%
lstm.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[model_checkpoint_callback, tensorboard_callback, text_generator],
)
# Out:
# Epoch 1/25
# 629/629 [==============================] - ETA: 0s - loss: 4.3765
# generated text:
# recipe for pine containing resting scotch rhubarb | bring boil until . olive and they butter in - beat , the radishes . sprinkle to your side flakes with parsley . 1 about 35 minutes . cook . work mixture after a apricots . about brown , then medium to the 2 oil to room coleslaw and floured brown and rises and medium bowl , until beat over water in when mortar with a inch verde or then pitas along into waxed salt
#
# 629/629 [==============================] - 175s 275ms/step - loss: 4.3765
# Epoch 2/25
# 629/629 [==============================] - ETA: 0s - loss: 3.0799
# generated text:
# recipe for slowest sake dip in herb sauce | preheat oven to 350°f . preheat oven to add mustard and
#
# 629/629 [==============================] - 166s 265ms/step - loss: 3.0799
# Epoch 3/25
# 629/629 [==============================] - ETA: 0s - loss: 2.5361
# generated text:
# recipe for stock alexander | heat 2 tablespoons oil in a large pot over medium heat . cool slightly . slice avocado and 1 / 2 platter . chive main meatballs and gently chop chutney until smooth . roast letting back over . from green rice and chill . skins . chill 1 tablespoon sugar , lemon juice , 2 tablespoons strips and transfer to baking container . mix all fennel , vanilla cooking cream , capers , or soy potato mixture with orange mayonnaise , 1 / 6 - remaining 2 teaspoon salt until smooth . run wilted 1
#
# 629/629 [==============================] - 180s 287ms/step - loss: 2.5361
# Epoch 4/25
# 629/629 [==============================] - ETA: 0s - loss: 2.2838
# generated text:
# recipe for mixed peach mustard wedge | pour the brown on a good heatproof shallow pieces , turning over it gently while fruit is drawn below ) puree , then transfer to a flutes . bake garlic in middle of oven and preheat to oven and preheat to broiler . add honey and turmeric and the mixture . in a bowl blend the teaspoons butter or olive oil , uncovered , or until just hold off . discard the fruits , them , drizzle the butter and rice the pulp over the the fish , then add the boil ,
#
# 629/629 [==============================] - 319s 507ms/step - loss: 2.2838
# Epoch 5/25
# 629/629 [==============================] - ETA: 0s - loss: 2.1345
# generated text:
# recipe for spinach and parmesan focaccia | using a 4 masher , transfer the beans to each plate , pressing around solids , and drain again . when opaque in a bowl keep the water on the heat . gently use the skin , transfer to a bowl with a mortar and salt in a glass baking pan . refrigerate . in a colander , place the center and giblets into a double tins and remove the way scraps . rub the veal under the dried loin , and damp smaller heavy knife ( disks should do not overwork apart
#
# 629/629 [==============================] - 444s 706ms/step - loss: 2.1345
# Epoch 6/25
# 629/629 [==============================] - ETA: 0s - loss: 2.0295
# generated text:
# recipe for stuffed dough with swiss beans , and dill salsa | cut surfaces are finely finely chop , into medium - size - even layer in ham . crumble frittata across . place on a box strips fitted with fork and onto racks with 1 / 4 cup round . unroll 1 1 / 4 inch large disk with scant half of chicken in 8 balls . press edge directly onto triangle and halve to 12 - inch round . cut the pith from peppers and nuts crosswise into ramekins , place . sprinkle scallion with other 1 /
#
# 629/629 [==============================] - 440s 699ms/step - loss: 2.0295
# Epoch 7/25
# 629/629 [==============================] - ETA: 0s - loss: 1.9504
# generated text:
# recipe for persian peach dried fruit with squash with garlic sauce | combine peaches , lemon juice , mustard , and 2 teaspoons fresh 1 / 4 teaspoon lime juice ( liquid will be darkened ) and the chicken reduces 1 more juice , stirring occasionally . continue cooking , stirring , 1 minute . drain the heat and pat dry of the oil . stack a grill several strips on top and devein skin breast , then invert the top of the pan plates . grill with peppercorn , mezcal or new lids in a stand about 2 hours
#
# 629/629 [==============================] - 437s 694ms/step - loss: 1.9504
# Epoch 8/25
# 629/629 [==============================] - ETA: 0s - loss: 1.8907
# generated text:
# recipe for eggplant , chorizo , and lamb stew | 1 . peel first , scoop shinier into 1 / 4 - inch - thick slices . transfer to a bowl , then toss with persimmons , any completely , until smooth . pour into measuring cup fluff dry . cover and stir heat to combine . add beef and cook , stirring occasionally , until crisp - tender . add lavender half and white wine and cook until syrupy and reduced , stirring occasionally , about 15 minutes . remove greens that center topped with icing .
#
# 629/629 [==============================] - 425s 675ms/step - loss: 1.8907
# Epoch 9/25
# 629/629 [==============================] - ETA: 0s - loss: 1.8422
# generated text:
# recipe for clarified chocolate grits | put oven rack in upper third of oven and preheat oven together potatoes . in a dry skillet with roasting pan mix together butter with juice . add a little butter , swirl just to distribute hot but cold water , cream , and simple syrup . bring to a boil over medium heat . add tomatoes among a medium - deep - bottomed skillet and cook until peas are just tender , about 12 minutes . add onion sprigs and stir over medium - low heat until mixture is thickened and top is
#
# 629/629 [==============================] - 462s 734ms/step - loss: 1.8422
# Epoch 10/25
# 629/629 [==============================] - ETA: 0s - loss: 1.8018
# generated text:
# recipe for mushroom corn salad with pesto coffee and harissa | melt brussels leaves in 1 tablespoon oil in a large heavy skillet over moderately high heat until foam subsides , then reduce heat and stir in rice to brown , about 5 minutes . add 30 seconds . when barely barely hot , puree brine and white peppercorns until just firm , about 1 hour . turn off ; pour cups shells into a food processor and whisk together lemon juice , mayonnaise , garlic , ginger , 2 tablespoons oil , olives , mustard seeds , oil ,
#
# 629/629 [==============================] - 445s 707ms/step - loss: 1.8018
# Epoch 11/25
# 629/629 [==============================] - ETA: 0s - loss: 1.7676
# generated text:
# recipe for grilled red potato soup in red pepper sauce | heat oil in small nonstick skillet over moderately high heat until hot but not brown on each full within . transfer sausages to prepared baking dish . sprinkle shrimp with chopped shallots and ginger . add garlic in 11x7x2 - gallon slotted spoon to paper towels by drain . add onion and breadcrumbs ; sauté until soft , about 4 minutes . season with salt . add onions to pot and sauté until chicken is beginning to brown , about 4 minutes . season ragout to taste with salt
#
# 629/629 [==============================] - 428s 680ms/step - loss: 1.7676
# Epoch 12/25
# 629/629 [==============================] - ETA: 0s - loss: 1.7379
# generated text:
# recipe for maple cream sauce with yogurt tangerine dice | if you are a screw yield add cracked herbs to whisked with salt . cut root meat and endives in stacks . with a skewer or each chicken slice with 2 , or half of halves slices in a food processor . wrap twelve 1 - inch - sized pieces with a mortar and pestle ( very crush mash ) , in a bowl with an electric mixer cream with a pinch of water and cheese , then rub with hot oil . add butter and juice and bring just
#
# 629/629 [==============================] - 451s 717ms/step - loss: 1.7379
# Epoch 13/25
# 629/629 [==============================] - ETA: 0s - loss: 1.7118
# generated text:
# recipe for charcoal - inspired spritzer | serve rabbit with cold water and just before serving , place the food processor and bourbon . have a grated top chilled glasses between glasses .
#
# 629/629 [==============================] - 418s 665ms/step - loss: 1.7118
# Epoch 14/25
# 629/629 [==============================] - ETA: 0s - loss: 1.6886
# generated text:
# recipe for 325°f and tasso flan | whisk first 4 ingredients in small bowl to blend . place chickpeas , coriander and salt in medium bowl . add enough water to measure 2 inches , blend until herbs are mixed . drop one third of crust into 24 patties . cover and chill penne while preparing italian layer of 1 piece at shiitakes . if using another use , lift any parts of personal marking slice across center and slice in center bottoms . cut each half and sandwich with arugula cheese . top with basil and crisp fish .
#
# 629/629 [==============================] - 455s 724ms/step - loss: 1.6886
# Epoch 15/25
# 629/629 [==============================] - ETA: 0s - loss: 1.6678
# generated text:
# recipe for sweet - thirds bread with beet and tomato sauce | preheat oven to 350°f . spray large rimmed baking sheet with medium nonstick . mix flour , salt and pepper in small bowl . set , stir egg yolks 1 / 4 cup canned olive into milk . beat in flour mixture , eggs , and vinegar . add butter and mustard and stir egg mixture until blended . increase heat ; add pod and spray ; sauté until most of rhubarb are just melted , adding additional milk if necessary . pour filling over pudding . bake
#
# 629/629 [==============================] - 259s 412ms/step - loss: 1.6678
# Epoch 16/25
# 629/629 [==============================] - ETA: 0s - loss: 1.6488
# generated text:
# recipe for cheesecake with moroccan fudge latkes | preheat oven to 350°f . butter four 3 - inch - deep ovenproof baking dish ( same pan ) . pour enough water into bowl to stiff bag at cornmeal . cover ; let stand until foamy , about 10 minutes . using electric mixer on high speed , fry until light brown , 10 minutes . drain and in small bowl whisk together mango , cream , oregano , and salt . add herb and stir mixture on low , adding more water by teaspoonfuls if very cold . gather crust
#
# 629/629 [==============================] - 183s 292ms/step - loss: 1.6488
# Epoch 17/25
# 629/629 [==============================] - ETA: 0s - loss: 1.6318
# generated text:
# recipe for veggie courtbouillon sandwiches | in a large skillet simmer the beans it in batches in a large saucepan ( preferably with nonstick 100 ) and whip until they have on the liquid given pan that they sink slightly . drain garlic and finely chop . total by putting a hot purée . place the cracker water in a shallow 13 - quart ( 23 - towel ) and chop them in a jar until it just holds together . spoon them into the cleaned - sized bag and add to skillet by placing to a baking sheet in
#
# 629/629 [==============================] - 180s 286ms/step - loss: 1.6318
# Epoch 18/25
# 629/629 [==============================] - ETA: 0s - loss: 1.6166
# generated text:
# recipe for linguine with chorizo , raisins , mushrooms , cherries , bay leaf , and lime leaves and chives | put oven rack in upper third of oven and preheat oven to 325°f . put flour in a large bowl . add 1 / 3 cup butter and stir gradually beat in butter over medium speed until just combined , then increase heat to low and rub in both flours and mix until combined well . add eggs , onions , celery , and herbs . rub mixture over and knead until dough is golden , about 5 minutes
#
# 629/629 [==============================] - 182s 289ms/step - loss: 1.6166
# Epoch 19/25
# 629/629 [==============================] - ETA: 0s - loss: 1.6036
# generated text:
# recipe for steamed ham with pickled eggplant | peel the chiles and the cucumbers across the potatoes in a bowl . pour water and 2 tablespoons of the trail into the wok over low heat , shaking the pan and allow to stop as they be to 2 more times to avoid burning . heat the butter to 450°f . remove meat from the heat and set aside . in a large measuring cup this in a saucepan heat butter with oil into a 3 of the blending just simmering water just just before adding it and barely thick some
#
# 629/629 [==============================] - 182s 290ms/step - loss: 1.6036
# Epoch 20/25
# 629/629 [==============================] - ETA: 0s - loss: 1.5888
# generated text:
# recipe for pineapple syrup cocktail | slice off orange quarter , then discard . cut each 1 half lengthwise into 1 / 8 - inch sticks ( 1 - sugar - inch ) juice ; using on / off turns , butter has smooth , scraping them solids and with a fork mash in almonds and purée until mixture resembles coarse meal with ice cubes in an ice and stir into 2 cups strawberry purée , dividing equally . pour custard into pastry bag , cover , and chill at least 1 hour or until very cold . chill 15
#
# 629/629 [==============================] - 180s 286ms/step - loss: 1.5888
# Epoch 21/25
# 629/629 [==============================] - ETA: 0s - loss: 1.5766
# generated text:
# recipe for citrus grilled rum | whisk orange juice , onion paste , lemon peel , and orange peel in a small bowl . whisk in 3 rosemary , chopped garlic , and 1 tablespoon ice water to a sugar . season with salt to taste and add to white , then cover and heat 2 tablespoons olive oil . slowly add water and bring to a boil . break 1 1 / 2 cups onto high , place it with pistachio juice mixture , cinnamon sticks , and 1 / 2 cup cold water . cover the cheesecloth and
#
# 629/629 [==============================] - 183s 290ms/step - loss: 1.5766
# Epoch 22/25
# 629/629 [==============================] - ETA: 0s - loss: 1.5654
# generated text:
# recipe for mussels with pickled tomatoes and tomatoes , spinach , and fennel | place a large heavy skillet in a kettle and let sit 24 minutes ; reserve . reserve 1 / 4 cup noodles and then halve remaining parsley . in a large saucepan heat 1 tablespoon oil and kombu 5 to 4 minutes on medium heat , add salt , pepper , and 1 / 2 cup , garlic , garlic , fennel seeds , and cilantro and gently simmer , stirring occasionally , for tomatoes , until heated through , about 5 minutes . add remaining
#
# 629/629 [==============================] - 181s 287ms/step - loss: 1.5654
# Epoch 23/25
# 629/629 [==============================] - ETA: 0s - loss: 1.5547
# generated text:
# recipe for banana granita | in a saucepan bring the applejack , water , sugar , and 1 tablespoon tapioca and boil until the fat is dissolved , form them into a ball . put the figs on it lined with the lined vegetable mixture , pour over the cocoa point 1 / 4 cup of the other cup each and let them dry , stir them into the bowl of ice and pour the riesling mixture into cream mixture in a glass jar with a heavy surface or a 20 15 minutes , or until top is thick ,
#
# 629/629 [==============================] - 180s 287ms/step - loss: 1.5547
# Epoch 24/25
# 629/629 [==============================] - ETA: 0s - loss: 1.5453
# generated text:
# recipe for steak purée | cut the meat into the smaller slice and chunky fat is cutting out . in a roasting pan toss the gingerroot , the onion , the caraway , the parsley , the pepper , and salt and pepper 30 seconds , stirring . spoon the cornstarch mixture among the casserole baking dish and divide the toasts among each crepes .
#
# 629/629 [==============================] - 182s 290ms/step - loss: 1.5453
# Epoch 25/25
# 629/629 [==============================] - ETA: 0s - loss: 1.5353
# generated text:
# recipe for spiced coconut lettuce with candied cashews | fill a cornmeal with / the pie mixer with an electric mixer with an electric mixer at medium - low speed until the mixture is fluffy and fluffy , about 5 seconds . add the eggs one at two of the process just until the mixture pulls away from the sides of the bowl from the lukewarm pie . remove the pastry time . ( 105°f for 1 . ) turn off the top and let cool . alternatively , when nuts are smooth , there will be about 1 cup
#
# 629/629 [==============================] - 183s 291ms/step - loss: 1.5353

# %%
# Save the final model
# lstm.save("./models/lstm")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/lstm\assets
# INFO:tensorflow:Assets written to: ./models/lstm\assets

# %%
# Load the model
lstm = models.load_model("./models/lstm", compile=False)
text_generator.model = lstm

# %%
#load model weights from h5 file
lstm.load_weights("./models/lstm.h5")
text_generator.model = lstm

# %% [markdown]
# ## 6. Generate text using the LSTM

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=50, temperature=0.2
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 / 2 teaspoon salt and 1 / 2

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	94.26%
# 4:   	5.73%
# 3:   	0.01%
# 8:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2
# cup:   	99.96%
# inch:   	0.04%
# teaspoon:   	0.0%
# -:   	0.0%
# tablespoon:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup
# cold:   	84.04%
# of:   	8.9%
# garlic:   	4.93%
# chopped:   	1.88%
# .:   	0.11%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold
# water:   	100.0%
# .:   	0.0%
# cooking:   	0.0%
# juice:   	0.0%
# ,:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water
# and:   	56.33%
# .:   	43.65%
# ;:   	0.02%
# in:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and
# reserve:   	63.55%
# place:   	18.95%
# drain:   	8.09%
# squeeze:   	6.38%
# add:   	1.03%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve
# .:   	99.11%
# 1:   	0.46%
# for:   	0.23%
# any:   	0.13%
# 2:   	0.04%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve .
# in:   	58.38%
# add:   	21.55%
# drain:   	8.27%
# cut:   	4.95%
# heat:   	4.89%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add
# 1:   	52.07%
# garlic:   	31.63%
# oil:   	10.84%
# onion:   	2.26%
# water:   	1.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1
# /:   	95.51%
# cup:   	3.99%
# tablespoon:   	0.49%
# 1:   	0.01%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 /
# 2:   	99.68%
# 4:   	0.32%
# 3:   	0.0%
# 8:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2
# cup:   	100.0%
# teaspoon:   	0.0%
# tablespoon:   	0.0%
# inch:   	0.0%
# cups:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup
# water:   	97.35%
# oil:   	2.65%
# of:   	0.0%
# cold:   	0.0%
# sugar:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water
# to:   	64.99%
# ,:   	23.59%
# and:   	11.34%
# in:   	0.08%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water ,
# then:   	67.22%
# 1:   	32.68%
# water:   	0.09%
# sugar:   	0.0%
# garlic:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1
# /:   	99.84%
# tablespoon:   	0.15%
# cup:   	0.0%
# at:   	0.0%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 /
# 2:   	99.2%
# 4:   	0.8%
# 3:   	0.0%
# 8:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2
# cup:   	99.96%
# teaspoon:   	0.04%
# tsp:   	0.0%
# tablespoon:   	0.0%
# inch:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup
# water:   	99.86%
# oil:   	0.07%
# at:   	0.05%
# of:   	0.03%
# sugar:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water
# ,:   	100.0%
# and:   	0.0%
# (:   	0.0%
# to:   	0.0%
# .:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water ,
# 1:   	97.4%
# and:   	2.58%
# 2:   	0.01%
# 3:   	0.0%
# sugar:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1
# /:   	100.0%
# tablespoon:   	0.0%
# cup:   	0.0%
# teaspoon:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 /
# 2:   	93.12%
# 4:   	6.88%
# 3:   	0.0%
# 8:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2
# cup:   	91.45%
# teaspoon:   	8.55%
# tsp:   	0.0%
# -:   	0.0%
# tablespoon:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup
# water:   	99.69%
# oil:   	0.24%
# of:   	0.04%
# at:   	0.02%
# sugar:   	0.01%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water
# ,:   	100.0%
# and:   	0.0%
# (:   	0.0%
# .:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water ,
# 1:   	93.19%
# and:   	6.8%
# 2:   	0.01%
# 3:   	0.0%
# salt:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1
# /:   	100.0%
# tablespoon:   	0.0%
# teaspoon:   	0.0%
# cup:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 /
# 2:   	93.31%
# 4:   	6.69%
# 3:   	0.0%
# 8:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2
# teaspoon:   	50.86%
# cup:   	49.14%
# tsp:   	0.0%
# tablespoon:   	0.0%
# -:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup
# water:   	99.72%
# oil:   	0.2%
# sugar:   	0.06%
# of:   	0.02%
# at:   	0.01%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water
# ,:   	100.0%
# and:   	0.0%
# .:   	0.0%
# (:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water ,
# 1:   	93.09%
# and:   	6.89%
# 2:   	0.01%
# salt:   	0.0%
# 3:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and
# 1:   	95.43%
# salt:   	4.55%
# 2:   	0.02%
# remaining:   	0.0%
# 3:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1
# /:   	99.99%
# 1:   	0.0%
# teaspoon:   	0.0%
# tablespoon:   	0.0%
# cup:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 /
# 2:   	83.41%
# 4:   	16.59%
# 3:   	0.0%
# 8:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 / 2
# teaspoon:   	97.74%
# cup:   	2.26%
# tsp:   	0.0%
# tablespoon:   	0.0%
# cups:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 / 2 teaspoon
# salt:   	99.97%
# pepper:   	0.03%
# coarse:   	0.0%
# cayenne:   	0.0%
# kosher:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 / 2 teaspoon salt
# and:   	99.55%
# .:   	0.43%
# until:   	0.01%
# ,:   	0.01%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 / 2 teaspoon salt and
# 1:   	95.55%
# let:   	1.3%
# blend:   	1.26%
# pulse:   	0.78%
# cook:   	0.7%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 / 2 teaspoon salt and 1
# /:   	100.0%
# 1:   	0.0%
# teaspoon:   	0.0%
# minute:   	0.0%
# tablespoon:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup cold water and reserve . add 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , 1 / 2 cup water , and 1 / 2 teaspoon salt and 1 /
# 2:   	95.63%
# 4:   	4.36%
# 3:   	0.0%
# 8:   	0.0%
# 1:   	0.0%
# --------

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=50, temperature=1
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer on a baking sheet and broil ,

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	55.63%
# 4:   	31.77%
# 3:   	8.94%
# 8:   	1.02%
# 1:   	0.63%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4
# cup:   	73.59%
# inch:   	16.32%
# teaspoon:   	2.08%
# -:   	1.69%
# of:   	1.1%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup
# cold:   	7.91%
# garlic:   	5.36%
# of:   	5.09%
# chopped:   	4.26%
# green:   	2.78%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts
# and:   	47.66%
# .:   	24.9%
# ;:   	7.52%
# in:   	6.4%
# with:   	3.97%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts .
# combine:   	8.19%
# in:   	8.01%
# heat:   	7.14%
# cut:   	6.95%
# place:   	6.11%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat
# oil:   	50.2%
# 1:   	9.76%
# 2:   	9.03%
# olive:   	4.76%
# a:   	3.37%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil
# in:   	94.07%
# and:   	1.07%
# ,:   	1.06%
# over:   	0.82%
# to:   	0.5%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil .
# add:   	25.52%
# oil:   	6.04%
# in:   	4.69%
# heat:   	3.86%
# place:   	3.16%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add
# 1:   	7.28%
# onion:   	7.11%
# garlic:   	6.71%
# oil:   	5.98%
# chicken:   	2.72%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion
# and:   	49.0%
# ,:   	37.71%
# to:   	4.51%
# ;:   	3.4%
# mixture:   	0.88%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion ,
# garlic:   	19.7%
# celery:   	10.25%
# bell:   	4.94%
# onion:   	4.71%
# carrot:   	3.88%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic
# ,:   	90.0%
# and:   	8.5%
# powder:   	0.69%
# cloves:   	0.09%
# paste:   	0.08%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic ,
# and:   	38.92%
# garlic:   	9.28%
# salt:   	3.19%
# cumin:   	2.81%
# ginger:   	2.31%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red
# pepper:   	63.68%
# onion:   	11.42%
# bell:   	10.47%
# -:   	3.75%
# peppers:   	2.77%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper
# flakes:   	78.62%
# ,:   	18.75%
# and:   	1.66%
# mixture:   	0.22%
# paste:   	0.2%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes
# ,:   	93.93%
# and:   	5.29%
# (:   	0.29%
# .:   	0.08%
# ;:   	0.07%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes ,
# and:   	47.13%
# salt:   	7.53%
# 1:   	4.96%
# garlic:   	3.71%
# cumin:   	2.92%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and
# salt:   	27.42%
# 1:   	10.34%
# garlic:   	5.88%
# 2:   	3.02%
# pepper:   	2.98%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt
# and:   	64.53%
# to:   	16.19%
# ;:   	5.91%
# .:   	5.23%
# ,:   	2.92%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and
# pepper:   	76.1%
# toss:   	2.36%
# blend:   	2.31%
# cook:   	2.14%
# pulse:   	1.82%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper
# to:   	68.09%
# and:   	14.59%
# .:   	7.49%
# ;:   	4.56%
# ,:   	2.91%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to
# taste:   	88.27%
# blend:   	1.61%
# a:   	0.9%
# pepper:   	0.59%
# oil:   	0.59%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste
# and:   	29.19%
# .:   	28.64%
# ,:   	22.83%
# in:   	9.92%
# ;:   	3.25%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and
# toss:   	20.82%
# cook:   	17.43%
# stir:   	10.16%
# add:   	5.7%
# season:   	4.29%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve
# .:   	16.99%
# oil:   	13.63%
# remaining:   	7.83%
# 1:   	7.01%
# skillet:   	4.1%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve .
# add:   	12.95%
# in:   	10.62%
# heat:   	10.33%
# pat:   	6.49%
# transfer:   	5.5%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook
# onion:   	7.69%
# potatoes:   	5.91%
# bacon:   	5.4%
# garlic:   	4.45%
# pasta:   	4.41%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic
# in:   	61.58%
# ,:   	17.95%
# and:   	7.95%
# until:   	2.14%
# cloves:   	1.72%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic ,
# garlic:   	14.98%
# 1:   	10.87%
# pepper:   	3.81%
# stirring:   	3.71%
# covered:   	3.59%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until
# just:   	6.44%
# golden:   	6.23%
# tender:   	4.82%
# fragrant:   	4.57%
# onion:   	3.74%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken
# is:   	90.7%
# begins:   	3.34%
# and:   	1.43%
# has:   	0.54%
# browns:   	0.36%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is
# just:   	21.04%
# cooked:   	15.92%
# tender:   	10.22%
# crisp:   	9.05%
# golden:   	7.39%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender
# ,:   	57.09%
# and:   	37.7%
# but:   	3.17%
# when:   	0.98%
# .:   	0.38%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and
# golden:   	6.34%
# beginning:   	5.8%
# browned:   	3.84%
# mixture:   	3.77%
# liquid:   	3.4%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing
# chicken:   	6.73%
# tomatoes:   	5.09%
# red:   	3.93%
# shrimp:   	3.66%
# cooked:   	3.31%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer
# of:   	36.66%
# with:   	18.47%
# on:   	10.84%
# ,:   	8.27%
# in:   	4.3%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer on
# a:   	22.61%
# all:   	14.67%
# both:   	13.99%
# top:   	7.49%
# bottom:   	6.86%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer on a
# baking:   	20.03%
# plate:   	18.07%
# rimmed:   	16.81%
# rack:   	6.88%
# large:   	6.12%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer on a baking
# sheet:   	98.52%
# pan:   	0.48%
# dish:   	0.26%
# tray:   	0.24%
# sheets:   	0.16%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer on a baking sheet
# and:   	36.04%
# ,:   	26.91%
# .:   	9.74%
# ;:   	8.96%
# in:   	3.88%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer on a baking sheet and
# roast:   	19.21%
# broil:   	13.44%
# bake:   	10.15%
# cook:   	7.21%
# toast:   	6.33%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4 cup nuts . heat oil . add onion , garlic , red pepper flakes , and salt and pepper to taste and reserve . cook garlic , until chicken is tender and glowing layer on a baking sheet and broil
# until:   	33.2%
# about:   	9.53%
# ,:   	6.94%
# 4:   	4.3%
# 2:   	3.68%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=200, temperature=0.5
)
#print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | bring 1 cup water to a boil in a 4 - quart heavy saucepan , then reduce heat to moderate and cook , stirring occasionally , until sugar is dissolved , about 2 minutes . remove from heat and let cool .
